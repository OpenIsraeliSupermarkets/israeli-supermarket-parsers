# %%
import pandas as pd

# %%
stores = pd.read_csv("stores.csv")
stores.head(10)
# Out:
#                                              file_id        chainid  \
# 0  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 1  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 2  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 3  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 4  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 5  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 6  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 7  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 8  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
# 9  samples_store/Super-Pharm/StoresFull7290172900...  7290172900007
#
#   subchainid  storeid bikoretno storetype        chainname subchainname  \
# 0        100        1       100         1  סופר פארם ישראל   NO-CONTENT
# 1        100        2       100         1  סופר פארם ישראל   NO-CONTENT
# 2        100        4       100         1  סופר פארם ישראל   NO-CONTENT
# 3        100        5       100         1  סופר פארם ישראל   NO-CONTENT
# 4        100        6       100         1  סופר פארם ישראל   NO-CONTENT
# 5        100        7       100         1  סופר פארם ישראל   NO-CONTENT
# 6        100        8       100         1  סופר פארם ישראל   NO-CONTENT
# 7        100        9       100         1  סופר פארם ישראל   NO-CONTENT
# 8        100       10       100         1  סופר פארם ישראל   NO-CONTENT
# 9        100       12       100         1  סופר פארם ישראל   NO-CONTENT
#
#                 storename                          address        city  \
# 0         סופר-פארם צמרות                            צמרות      הרצליה
# 1          סופר-פארם ניות                             ניות     ירושלים
# 2       סופר-פארם משחררים                  רח' המשחררים 70     באר-שבע
# 3    סופר-פארם בית אמריקה             בית אמריקה פתח תקווה    פתח-תקוה
# 4         סופר-פארם אורון                  רוטשילד 182 פ"ת    פתח-תקוה
# 5          סופר-פארם גילה                             גילה     ירושלים
# 6      סופר-פארם רמת אביב  איינשטיין 40 קניון אביב תל-אביב     תל-אביב
# 7       סופר-פארם כפר סבא                 ויצמן 76 כפר סבא     כפר-סבא
# 8  סופר-פארם קניון איילון                      אבא הלל 165      רמת גן
# 9    סופר-פארם גבעת סביון       הגליל 78 , מרכז גבעת סביון  גבעת סביון
#
#   zipcode   lastupdatedatetime doclastupdatedatetime  is_online
# 0       0  2022-10-20 02:00:01               unknown      False
# 1       0  2022-10-20 02:00:01               unknown      False
# 2       0  2022-10-20 02:00:01               unknown      False
# 3       0  2022-10-20 02:00:01               unknown      False
# 4       0  2022-10-20 02:00:01               unknown      False
# 5       0  2022-10-20 02:00:01               unknown      False
# 6       0  2022-10-20 02:00:01               unknown      False
# 7       0  2022-10-20 02:00:01               unknown      False
# 8       0  2022-10-20 02:00:01               unknown      False
# 9       0  2022-10-20 02:00:01               unknown      False

# %%
stores.columns
# Out:
# Index(['file_id', 'chainid', 'subchainid', 'storeid', 'bikoretno', 'storetype',
#        'chainname', 'subchainname', 'storename', 'address', 'city', 'zipcode',
#        'lastupdatedatetime', 'doclastupdatedatetime', 'is_online'],
#       dtype='object')

# %%
# those are the date columns
date_columns = ['lastupdatedatetime', 'doclastupdatedatetime']

# %%
stores['dt_lastupdatedatetime'] =  pd.to_datetime(stores['lastupdatedatetime'],errors='coerce')
stores['dt_doclastupdatedatetime'] =  pd.to_datetime(stores['doclastupdatedatetime'],errors='coerce')

# %%
recoeds_with_dt = stores[stores[['dt_lastupdatedatetime','dt_doclastupdatedatetime']].isna().all(axis=1)]
recoeds_with_dt[['lastupdatedatetime','doclastupdatedatetime']].head()

# never as '01/01/0001 00:00:00' which is basicly 'never'
# Out:
#      lastupdatedatetime doclastupdatedatetime
# 2236              never               unknown
# 2731              never               unknown
# 2732              never               unknown

# %%
names_columns = ['storename','chainname']
words_indacting_online = ['אונליין','אינטרנט']

# %%
stores['chainname'].value_counts()
# Out:
# סופר פארם ישראל                             843
# Dor Alon                                    555
# פז חברת הנפט בע"מ                           490
# שופרסל                                      406
# גוד פארם בע"מ                               138
# מ. יוחננוף ובניו                            132
# פרש מרקט                                    129
# רמי לוי שיווק השקמה                         116
# טיב טעם                                     114
# שפע  ברכת השם בע"מ                          100
# פז חברת נפט בע"מ                             88
# נתיב החסד- סופר חסד בע"מ                     86
# מגה בעיר                                     86
# אלמשהדאוי קינג סטור בע"מ                     84
# ג.מ. מעיין אלפיים (07) בע"מ                  72
# זול ובגדול בע"מ                              70
# ויקטורי                                      65
# סטופמרקט                                     60
# יינות ביתן                                   59
# אושר עד                                      57
# קשת טעמים                                    42
# רמי לוי בשכונה                               40
# כל בו חצי חינם                               24
# מחסני השוק                                   17
# Dabach                                       15
# ברקת                                         13
# רשת חנויות רמי לוי שיווק השקמה 2006 בע"מ      8
# מגה מרקט                                      3
# Name: chainname, dtype: int64

# %%
stores['storename'].value_counts()
# Out:
# באר שבע                18
# כרמיאל                 16
# אשדוד                  15
# ראשון לציון            14
# חדרה                   13
#                        ..
# 72 אשדוד הפלמ"ח (ג)     1
# 75 טבריה הדר            1
# 76 צפת                  1
# 77 קרית גת              1
# רחובות C  NH ברכל       1
# Name: storename, Length: 1801, dtype: int64

# %%
stores['is_online'].value_counts()
# Out:
# False    3866
# True       46
# Name: is_online, dtype: int64

# %%
address_columns = ['address', 'city', 'zipcode','is_online']

# %%
from kniot_parser.utils import get_scraper_name_from_id,get_all_scrapers_names

# %%
chains_with_online = stores.loc[stores.is_online]["chainid"].unique()
chains_with_online = list(map(get_scraper_name_from_id,chains_with_online))
chains_without_online = set(get_all_scrapers_names()) - set(chains_with_online)
# Out:
# mylogger     2022-10-25 10:59:57,536 INFO     logger.py:info Storage path: dumps/bareket
# ['7290875100001']
# mylogger     2022-10-25 10:59:57,538 INFO     logger.py:info Storage path: dumps/bareket
# mylogger     2022-10-25 10:59:57,539 INFO     logger.py:info Storage path: dumps/ybitan
# ['7290725900003']
# mylogger     2022-10-25 10:59:57,540 INFO     logger.py:info Storage path: dumps/ybitan
# mylogger     2022-10-25 10:59:57,540 INFO     logger.py:info Storage path: dumps/cofix
# ['7291056200008']
# mylogger     2022-10-25 10:59:57,541 INFO     logger.py:info Storage path: dumps/cofix
# mylogger     2022-10-25 10:59:57,541 INFO     logger.py:info Storage path: dumps/Dor Alon
# ['7290492000005']
# mylogger     2022-10-25 10:59:57,542 INFO     logger.py:info Storage path: dumps/Dor Alon
# mylogger     2022-10-25 10:59:57,543 INFO     logger.py:info Storage path: dumps/GoodPharm
# ['7290058197699']
# mylogger     2022-10-25 10:59:57,544 INFO     logger.py:info Storage path: dumps/GoodPharm
# mylogger     2022-10-25 10:59:57,544 INFO     logger.py:info Storage path: dumps/Hazi Hinam
# ['7290700100008']
# mylogger     2022-10-25 10:59:57,545 INFO     logger.py:info Storage path: dumps/Hazi Hinam
# mylogger     2022-10-25 10:59:57,546 INFO     logger.py:info Storage path: dumps/Keshet Taamim
# ['7290785400000']
# mylogger     2022-10-25 10:59:57,547 INFO     logger.py:info Storage path: dumps/Keshet Taamim
# mylogger     2022-10-25 10:59:57,547 INFO     logger.py:info Storage path: dumps/King Store
# ['7290058108879']
# mylogger     2022-10-25 10:59:57,548 INFO     logger.py:info Storage path: dumps/King Store
# mylogger     2022-10-25 10:59:57,549 INFO     logger.py:info Storage path: dumps/Maayan2000
# ['7290058159628']
# mylogger     2022-10-25 10:59:57,550 INFO     logger.py:info Storage path: dumps/Maayan2000
# mylogger     2022-10-25 10:59:57,550 INFO     logger.py:info Storage path: dumps/mahsani a shuk
# ['7290661400001', '7290633800006']
# mylogger     2022-10-25 10:59:57,551 INFO     logger.py:info Storage path: dumps/mahsani a shuk
# mylogger     2022-10-25 10:59:57,552 INFO     logger.py:info Storage path: dumps/mega-market
# ['7290055700014']
# mylogger     2022-10-25 10:59:57,552 INFO     logger.py:info Storage path: dumps/mega-market
# mylogger     2022-10-25 10:59:57,553 INFO     logger.py:info Storage path: dumps/mega
# ['7290055700007']
# mylogger     2022-10-25 10:59:57,554 INFO     logger.py:info Storage path: dumps/mega
# mylogger     2022-10-25 10:59:57,555 INFO     logger.py:info Storage path: dumps/Netiv Hasef
# ['7290058160839']
# mylogger     2022-10-25 10:59:57,555 INFO     logger.py:info Storage path: dumps/Netiv Hasef
# mylogger     2022-10-25 10:59:57,556 INFO     logger.py:info Storage path: dumps/Osher Ad
# ['7290103152017']
# mylogger     2022-10-25 10:59:57,557 INFO     logger.py:info Storage path: dumps/Osher Ad
# mylogger     2022-10-25 10:59:57,557 INFO     logger.py:info Storage path: dumps/Polizer
# ['7291059100008']
# mylogger     2022-10-25 10:59:57,558 INFO     logger.py:info Storage path: dumps/Polizer
# mylogger     2022-10-25 10:59:57,559 INFO     logger.py:info Storage path: dumps/Rami Levy
# ['7290058140886']
# mylogger     2022-10-25 10:59:57,560 INFO     logger.py:info Storage path: dumps/Rami Levy
# mylogger     2022-10-25 10:59:57,560 INFO     logger.py:info Storage path: dumps/bareket
# ['7290875100001']
# mylogger     2022-10-25 10:59:57
# mylogger     2022-10-25 10:59:57,762 INFO     logger.py:info Storage path: dumps/Dor Alon
# ['7290492000005']
# mylogger     2022-10-25 10:59:57,763 INFO     logger.py:info Storage path: dumps/Dor Alon
# mylogger     2022-10-25 10:59:57,763 INFO     logger.py:info Storage path: dumps/GoodPharm
# ['7290058197699']
# mylogger     2022-10-25 10:59:57,764 INFO     logger.py:info Storage path: dumps/GoodPharm
# mylogger     2022-10-25 10:59:57,765 INFO     logger.py:info Storage path: dumps/Hazi Hinam
# ['7290700100008']
# mylogger     2022-10-25 10:59:57,766 INFO     logger.py:info Storage path: dumps/Hazi Hinam
# mylogger     2022-10-25 10:59:57,766 INFO     logger.py:info Storage path: dumps/Keshet Taamim
# ['7290785400000']
# mylogger     2022-10-25 10:59:57,767 INFO     logger.py:info Storage path: dumps/Keshet Taamim

# %%
chains_without_online
# Bareket as no online store
# 'Bareket','FreshMarketAndSuperDosh','Cofix','GoodPharm' as no online store

# 'KingStore' is during constraction 

going to work on: working on store vs all stores
# Out:
# {'Bareket',
#  'Cofix',
#  'FreshMarketAndSuperDosh',
#  'GoodPharm',
#  'KingStore',
#  'MegaMarket',
#  'Osherad',
#  'Polizer',
#  'SalachDabach',
#  'ShefaBarcartAshem',
#  'Shufersal',
#  'StopMarket',
#  'SuperPharm',
#  'SuperYuda',
#  'YaynotBitan',
#  'Yellow',
#  'Yohananof',
#  'ZolVeBegadol'}

# %%
# stores[((stores[address_columns] == 'NO-CONTENT').any(axis=1))]

# %%
test = stores[(stores[address_columns]['city'] == "unknown") & (~stores['is_online'])]
test['chainname'].unique()
# Out:
# array(['זול ובגדול בע"מ', 'יינות ביתן', 'פרש מרקט',
#        'אלמשהדאוי קינג סטור בע"מ', 'מ. יוחננוף ובניו', 'Dabach',
#        'פז חברת נפט בע"מ', 'נתיב החסד- סופר חסד בע"מ'], dtype=object)

# %%
test = stores[(stores[address_columns]['address'] == "unknown") & (~stores['is_online'])]
test['chainname'].unique()
# Out:
# array(['טיב טעם', 'זול ובגדול בע"מ', 'אלמשהדאוי קינג סטור בע"מ',
#        'מ. יוחננוף ובניו', 'Dabach'], dtype=object)

# %%
# נתיב החסד- סופר חסד בע"מ -> for store name
# יינות ביתן -> from store name
# זול ובגדול בע"מ -> no information
#  פז חברת נפט בע"מ -> store name
# אלמשהדאוי קינג סטור בע"מ' -> no inforamtion
# Dabach -> no inforamtion
# 'פרש מרקט' -> store name
# מ. יוחננוף ובניו -> store name 

#data_frame = data_frame.drop(columns=['zipcode'])
def fix_address(x):
    address_can_be_found_in_name = [ 'יינות ביתן', 'פרש מרקט', 'מ. יוחננוף ובניו', 'פז חברת נפט בע"מ', 'נתיב החסד- סופר חסד בע"מ']
    if x['city'] != 'unknown' and x['address'] != "unknown":
        return x['city'] + " , " + x['address']
    if x['city'] == 'unknown' and x['chainname'] in address_can_be_found_in_name:
        return x['storename']
    return x['city']

stores['location'] = stores.apply(fix_address,axis=1)

# %%
stores[(stores['location'] == "unknown") & (~stores['is_online'])]['chainname'].unique()
# Out:
# array(['זול ובגדול בע"מ', 'אלמשהדאוי קינג סטור בע"מ', 'Dabach'],
#       dtype=object)

# %%
stores.to_csv("f.csv")

# %%
exact_store = ['chainid', 'subchainid', 'storeid']
